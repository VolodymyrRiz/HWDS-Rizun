# %%
import pandas as pd
import numpy as np

# Завантажте CSV-файл у DataFrame pandas з використанням кодування cp1251
table = pd.read_csv('2017_jun_final.csv')

# Виведіть перші рядки таблиці
print('_________________________________________________________')
print("ПЕРШІ РЯДКИ ТАБЛИЦІ")
print(table.head(5))        

# Виведіть інформацію про таблицю
print('_________________________________________________________')
print("ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ:")
rows, columns = table.shape
print(f"Кількість рядків: {rows}")
print(f"Кількість стовпців: {columns}")

# Виведіть типи даних кожного стовпця
print('Типи всіх стовпців:')
print(table.dtypes)

# Обчисліть відсоток пропусків в кожному стовпці після заміни
missing_percentages = table.isnull().sum() / len(table) * 100

# Виведіть інформацію про таблицю
print('_________________________________________________________')
print("ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ.")
print('Частка пропусків, що міститься в кожній колонці: ')
print(missing_percentages)

# Замініть всі пропуски на NaN
table.replace('', np.nan, inplace=True)

# Виведіть оновлену таблицю
print('_________________________________________________________')
print("ТАБЛИЦЯ ПІСЛЯ ЗАМІНИ ПРОПУСКІВ НА NaN:")
print(table.head(5))


# Визначте назви колонок, які треба вилучити
columns_to_drop = [3, 14, 17, 23, 24]  # Віднімаємо одиницю, оскільки індексація починається з 0

# Вилучіть вказані колонки
table_updated = table.drop(table.columns[columns_to_drop], axis=1)

# Виведіть оновлену таблицю
print('_________________________________________________________')
print("ТАБЛИЦЯ ПІСЛЯ ВИДАЛЕННЯ ВИБРАНИХ СТОВПЦІВ:")
print(table_updated.head(5))

# Обчисліть відсоток пропусків в кожному стовпці після заміни
missing_percentages = table_updated.isnull().sum() / len(table) * 100

# Виведіть інформацію про таблицю
print('_________________________________________________________')
print("ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ.")
print('Частка пропусків, що міститься в кожній колонці після видалення стовпців, окрім МОВА ПРОГРАМУВАННЯ: ')
print(missing_percentages)

# Створіть нову таблицю python_data, яка містить тільки рядки зі спеціалістами, які вказали мову програмування Python
python_data = table_updated[table_updated[table_updated.columns[2]] == 'Python']

# Виведіть нову таблицю python_data
print('_________________________________________________________')
print("ТАБЛИЦЯ З РЯДКАМИ, ЯКІ ВИБРАЛИ МОВУ ПРОГРАМУВАННЯ 'Python':")
print(python_data)

# Виведіть інформацію про таблицю python_data
print('_________________________________________________________')
print("ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ python_data:")
rows, columns = python_data.shape
print(f"Кількість рядків: {rows}")
print(f"Кількість стовпців: {columns}")

# Видаліть всі рядки з таблиці table_updated
table_updated = table_updated.drop(table_updated.index)

# Виведіть оновлену таблицю
print('_________________________________________________________')
print("ВИХІДНА ТАБЛИЦЯ - не  python_data - ПІСЛЯ ВИДАЛЕННЯ ВСІХ РЯДКІВ:")
print(table_updated)

# Виведіть інформацію про таблицю після видалення всіх рядків
print('_________________________________________________________')
print("ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ:")
rows, columns = table_updated.shape
print(f"Кількість рядків: {rows}")
print(f"Кількість стовпців: {columns}")

# Виконайте групування за стовпчиком "Посада" для таблиці python_data
grouped_data = python_data.groupby('Посада')

# Виведіть групувані дані
print('_________________________________________________________')
print("ГРУПУВАННЯ ЗА СТОВПЦЕМ 'ПОСАДА' ДЛЯ ТАБЛИЦІ python_data:")
print(grouped_data.first())  # Виводимо перший елемент кожного групи

# Виведіть інформацію про групувані дані
print('_________________________________________________________')
print("ІНФОРМАЦІЯ ПРО ГРУПИ:")
for name, group in grouped_data:
    print(f"Група '{name}' має {len(group)} елементів")
    
# Знайдіть мінімальне та максимальне значення у стовпчику "Зарплата на місяць" для кожної групи
aggregated_data = grouped_data['Зарплата на місяць'].agg(['min', 'max'])

# Виведіть агреговані дані
print('_________________________________________________________')
print("АГРЕГАЦІЯ ЗА СТОВПЦЕМ 'ПОСАДА' ДЛЯ ТАБЛИЦІ python_data:")
print(aggregated_data)

# Функція для обчислення середньої заробітної плати
def fill_avg_salary(row):
    return row.mean()

# Застосування функції fill_avg_salary до кожного рядка DataFrame aggregated_data
aggregated_data['avg'] = aggregated_data.apply(fill_avg_salary, axis=1)

# Виведіть агреговані дані з новим стовпчиком "avg"
print('_________________________________________________________')
print("АГРЕГАЦІЯ ЗА СТОВПЦЕМ 'ПОСАДА' ДЛЯ ТАБЛИЦІ python_data З НОВИМ СТОВПЦЕМ 'avg':")
print(aggregated_data)

# Збережіть DataFrame aggregated_data у файл CSV
aggregated_data.to_csv('aggregated_data1.csv', index=False)

# Створення описової статистики для стовпчика "avg"
avg_stats = aggregated_data['avg'].describe()

# Виведіть описову статистику для стовпчика "avg"
print('_________________________________________________________')
print("ОПИСОВА СТАТИСТИКА ДЛЯ СТОВПЦЯ 'avg':")
print(avg_stats)

# Збережіть DataFrame python_data у файл CSV
python_data.to_csv('python_data.csv', index=False)
# Out:
# _________________________________________________________
# ПЕРШІ РЯДКИ ТАБЛИЦІ
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# 1                 430                           130  Харків  більше 1000 осіб
# 2                2500                           800    Київ      до 1000 осіб
# 3                2000                           400   Одеса       до 200 осіб
# 4                4500                           500    Інше        до 10 осіб
#
#    ... Ще студент                    Рівень англійської  \
# 0  ...       True    Pre-intermediate (нище середнього)
# 1  ...       True  Upper-Intermediate (вище середнього)
# 2  ...      False               Intermediate (середній)
# 3  ...      False    Pre-intermediate (нище середнього)
# 4  ...      False               Intermediate (середній)
#
#                    Предметна область      Дата заповнення  \
# 0                      iOS,eCommerce  12/06/2017 12:38:08
# 1                       Веб-розробка  12/06/2017 12:42:51
# 2  Веб-розробка,Корпоративні системи  12/06/2017 13:02:47
# 3  Desktop Applications,Веб-розробка  12/06/2017 13:03:01
# 4  Desktop Applications,Веб-розробка  12/06/2017 13:03:47
#
#                                           User.Agent   exp current_job_exp  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5             0.5
# 1  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0             0.0
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0             1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0             4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0             0.5
#
#   salary Валюта  cls
# 0    400    NaN   QA
# 1    430    NaN   QA
# 2   2500    NaN  DEV
# 3   2000    NaN  DEV
# 4   4500    NaN  DEV
#
# [5 rows x 25 columns]
# _________________________________________________________
# ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ:
# Кількість рядків: 8704
# Кількість стовпців: 25
# Типи всіх стовпців:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object
# _________________________________________________________
# ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ.
# Частка пропусків, що міститься в кожній колонці:
# N                                    0.000000
# Посада                               0.000000
# Мова програмування                  44.232537
# Спеціалізація                       82.938879
# Загальний досвід роботи              0.000000
# Досвід роботи на поточному місці     0.000000
# Зарплата на місяць                   0.000000
# Зміна зарплати за 12 місяців         0.000000
# Місто                                0.000000
# Розмір компанії                      0.000000
# Тип компанії                         0.000000
# Стать                                0.000000
# Вік                                  0.000000
# Освіта                               0.000000
# Університет                          4.113051
# Ще студент                           0.000000
# Рівень англійської                   0.000000
# Предметна область                    2.562040
# Дата заповнення                      0.000000
# User.Agent                           0.000000
# exp                                  0.000000
# current_job_exp                      0.000000
# salary                               0.000000
# Валюта                              99.885110
# cls                                 18.083640
# dtype: float64
# _________________________________________________________
# ТАБЛИЦЯ ПІСЛЯ ЗАМІНИ ПРОПУСКІВ НА NaN:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# 1                 430                           130  Харків  більше 1000 осіб
# 2                2500                           800    Київ      до 1000 осіб
# 3                2000                           400   Одеса       до 200 осіб
# 4                4500                           500    Інше        до 10 осіб
#
#    ... Ще студент                    Рівень англійської  \
# 0  ...       True    Pre-intermediate (нище середнього)
# 1  ...       True  Upper-Intermediate (вище середнього)
# 2  ...      False               Intermediate (середній)
# 3  ...      False    Pre-intermediate (нище середнього)
# 4  ...      False               Intermediate (середній)
#
#                    Предметна область      Дата заповнення  \
# 0                      iOS,eCommerce  12/06/2017 12:38:08
# 1                       Веб-розробка  12/06/2017 12:42:51
# 2  Веб-розробка,Корпоративні системи  12/06/2017 13:02:47
# 3  Desktop Applications,Веб-розробка  12/06/2017 13:03:01
# 4  Desktop Applications,Веб-розробка  12/06/2017 13:03:47
#
#                                           User.Agent   exp current_job_exp  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5             0.5
# 1  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0             0.0
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0             1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0             4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0             0.5
#
#   salary Валюта  cls
# 0    400    NaN   QA
# 1    430    NaN   QA
# 2   2500    NaN  DEV
# 3   2000    NaN  DEV
# 4   4500    NaN  DEV
#
# [5 rows x 25 columns]
# _________________________________________________________
# ТАБЛИЦЯ ПІСЛЯ ВИДАЛЕННЯ ВИБРАНИХ СТОВПЦІВ:
#    N                    Посада Мова програмування Загальний досвід роботи  \
# 0  1        Junior QA engineer                NaN                     0.5
# 1  2        Junior QA engineer                NaN         менше 3 місяців
# 2  3         Software Engineer            C#/.NET                       4
# 3  4         Software Engineer         JavaScript                       5
# 4  5  Senior Software Engineer         JavaScript       10 і більше років
#
#   Досвід роботи на поточному місці  Зарплата на місяць  \
# 0                              0.5                 400
# 1                  менше 3 місяців                 430
# 2                                1                2500
# 3                                4                2000
# 4                              0.5                4500
#
#    Зміна зарплати за 12 місяців   Місто   Розмір компанії   Тип компанії  \
# 0                             0  Харків        до 10 осіб  Аутсорсингова
# 1                           130  Харків  більше 1000 осіб  Аутсорсингова
# 2                           800    Київ      до 1000 осіб  Аутсорсингова
# 3                           400   Одеса       до 200 осіб     Продуктова
# 4                           500    Інше        до 10 осіб     Продуктова
#
#       Стать  Вік             Освіта  Ще студент  \
# 0    жіноча   20       Неповна Вища        True
# 1    жіноча   21       Неповна Вища        True
# 2  чоловіча   26               Вища       False
# 3  чоловіча   30            Середня       False
# 4  чоловіча   30  Технікум / Коледж       False
#
#                      Рівень англійської      Дата заповнення  \
# 0    Pre-intermediate (нище середнього)  12/06/2017 12:38:08
# 1  Upper-Intermediate (вище середнього)  12/06/2017 12:42:51
# 2               Intermediate (середній)  12/06/2017 13:02:47
# 3    Pre-intermediate (нище середнього)  12/06/2017 13:03:01
# 4               Intermediate (середній)  12/06/2017 13:03:47
#
#                                           User.Agent   exp  current_job_exp  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5              0.5
# 1  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0              0.0
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0              1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0              4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0              0.5
#
#    salary
# 0     400
# 1     430
# 2    2500
# 3    2000
# 4    4500
# _________________________________________________________
# ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ.
# Частка пропусків, що міститься в кожній колонці після видалення стовпців, окрім МОВА ПРОГРАМУВАННЯ:
# N                                    0.000000
# Посада                               0.000000
# Мова програмування                  44.232537
# Загальний досвід роботи              0.000000
# Досвід роботи на поточному місці     0.000000
# Зарплата на місяць                   0.000000
# Зміна зарплати за 12 місяців         0.000000
# Місто                                0.000000
# Розмір компанії                      0.000000
# Тип компанії                         0.000000
# Стать                                0.000000
# Вік                                  0.000000
# Освіта                               0.000000
# Ще студент                           0.000000
# Рівень англійської                   0.000000
# Дата заповнення                      0.000000
# User.Agent                           0.000000
# exp                                  0.000000
# current_job_exp                      0.000000
# salary                               0.000000
# dtype: float64
# _________________________________________________________
# ТАБЛИЦЯ З РЯДКАМИ, ЯКІ ВИБРАЛИ МОВУ ПРОГРАМУВАННЯ 'Python':
#          N                    Посада Мова програмування  \
# 12      13         Software Engineer             Python
# 68      69         Software Engineer             Python
# 87      88  Junior Software Engineer             Python
# 114    115  Junior Software Engineer             Python
# 143    144  Junior Software Engineer             Python
# ...    ...                       ...                ...
# 8546  8547         Software Engineer             Python
# 8625  8626         Software Engineer             Python
# 8635  8636  Senior Software Engineer             Python
# 8673  8674  Junior Software Engineer             Python
# 8695  8696         Software Engineer             Python
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# 68                       1.5                              0.5
# 87                       0.5                              0.5
# 114                      1.5                              0.5
# 143                        1                                1
# ...                      ...                              ...
# 8546                       5                                1
# 8625                       4                                1
# 8635       10 і більше років                  менше 3 місяців
# 8673                     0.5                              0.5
# 8695                       1                              0.5
#
#       Зарплата на місяць  Зміна зарплати за 12 місяців      Місто  \
# 12                   800                           200       Київ
# 68                   900                           900       Київ
# 87                   600                             0       Київ
# 114                  685                           250       Київ
# 143                  750                           250       Київ
# ...                  ...                           ...        ...
# 8546                2000                           800  Запоріжжя
# 8625                1750                             0       Київ
# 8635                4000                          1300  Віддалено
# 8673                 350                            50       Київ
# 8695                1500                          1000       Київ
#
#        Розмір компанії   Тип компанії     Стать  Вік        Освіта  \
# 12          до 50 осіб  Аутсорсингова  чоловіча   26          Вища
# 68          до 10 осіб        Стартап  чоловіча   21  Неповна Вища
# 87          до 10 осіб  Аутсорсингова  чоловіча   19  Неповна Вища
# 114       до 1000 осіб  Аутсорсингова  чоловіча   21  Неповна Вища
# 143         до 10 осіб  Аутсорсингова  чоловіча   21  Неповна Вища
# ...                ...            ...       ...  ...           ...
# 8546        до 50 осіб  Аутсорсингова  чоловіча   22  Неповна Вища
# 8625  більше 1000 осіб  Аутсорсингова  чоловіча   28       Середня
# 8635        до 10 осіб        Стартап  чоловіча   33          Вища
# 8673        до 50 осіб  Аутсорсингова  чоловіча   22          Вища
# 8695        до 10 осіб        Стартап  чоловіча   29          Вища
#
#       Ще студент                    Рівень англійської      Дата заповнення  \
# 12         False    Pre-intermediate (нище середнього)  12/06/2017 13:05:54
# 68          True  Upper-Intermediate (вище середнього)  12/06/2017 13:11:17
# 87          True  Upper-Intermediate (вище середнього)  12/06/2017 13:12:25
# 114        False               Intermediate (середній)  12/06/2017 13:14:52
# 143         True  Upper-Intermediate (вище середнього)  12/06/2017 13:19:10
# ...          ...                                   ...                  ...
# 8546       False               Intermediate (середній)  10/07/2017 14:11:26
# 8625       False               Intermediate (середній)  11/07/2017 16:15:40
# 8635       False  Upper-Intermediate (вище середнього)  11/07/2017 17:51:36
# 8673       False               Intermediate (середній)   12/07/2017 9:37:16
# 8695       False               Intermediate (середній)  12/07/2017 14:39:21
#
#                                              User.Agent   exp  \
# 12    Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   1.0
# 68    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.5
# 87    Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   0.5
# 114   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.5
# 143   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
# ...                                                 ...   ...
# 8546  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...   5.0
# 8625  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   4.0
# 8635  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  10.0
# 8673  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   0.5
# 8695  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
#
#       current_job_exp  salary
# 12                0.0     800
# 68                0.5     900
# 87                0.5     600
# 114               0.5     685
# 143               1.0     750
# ...               ...     ...
# 8546              1.0    2000
# 8625              1.0    1750
# 8635              0.0    4000
# 8673              0.5     350
# 8695              0.5    1500
#
# [207 rows x 20 columns]
# _________________________________________________________
# ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ python_data:
# Кількість рядків: 207
# Кількість стовпців: 20
# _________________________________________________________
# ВИХІДНА ТАБЛИЦЯ - не  python_data - ПІСЛЯ ВИДАЛЕННЯ ВСІХ РЯДКІВ:
# Empty DataFrame
# Columns: [N, Посада, Мова програмування, Загальний досвід роботи, Досвід роботи на поточному місці, Зарплата на місяць, Зміна зарплати за 12 місяців, Місто, Розмір компанії, Тип компанії, Стать, Вік, Освіта, Ще студент, Рівень англійської, Дата заповнення, User.Agent, exp, current_job_exp, salary]
# Index: []
# _________________________________________________________
# ІНФОРМАЦІЯ ПРО ТАБЛИЦЮ:
# Кількість рядків: 0
# Кількість стовпців: 20
# _________________________________________________________
# ГРУПУВАННЯ ЗА СТОВПЦЕМ 'ПОСАДА' ДЛЯ ТАБЛИЦІ python_data:
#                              N Мова програмування Загальний досвід роботи  \
# Посада
# Junior Software Engineer    88             Python                     0.5
# Senior Software Engineer   303             Python       10 і більше років
# Software Engineer           13             Python                       1
# System Architect          5749             Python       10 і більше років
# Technical Lead            2633             Python                       4
#
#                          Досвід роботи на поточному місці  Зарплата на місяць  \
# Посада
# Junior Software Engineer                              0.5                 600
# Senior Software Engineer                              0.5                3500
# Software Engineer                         менше 3 місяців                 800
# System Architect                                     0.25                3000
# Technical Lead                                        1.5                3500
#
#                           Зміна зарплати за 12 місяців Місто Розмір компанії  \
# Посада
# Junior Software Engineer                             0  Київ      до 10 осіб
# Senior Software Engineer                          -300  Київ     до 200 осіб
# Software Engineer                                  200  Київ      до 50 осіб
# System Architect                                     0  Київ      до 50 осіб
# Technical Lead                                    1000  Київ      до 50 осіб
#
#                            Тип компанії     Стать  Вік        Освіта  \
# Посада
# Junior Software Engineer  Аутсорсингова  чоловіча   19  Неповна Вища
# Senior Software Engineer     Продуктова  чоловіча   30          Вища
# Software Engineer         Аутсорсингова  чоловіча   26          Вища
# System Architect             Продуктова  чоловіча   40          Вища
# Technical Lead               Продуктова  чоловіча   23  Неповна Вища
#
#                           Ще студент                    Рівень англійської  \
# Посада
# Junior Software Engineer        True  Upper-Intermediate (вище середнього)
# Senior Software Engineer       False  Upper-Intermediate (вище середнього)
# Software Engineer              False    Pre-intermediate (нище середнього)
# System Architect               False  Upper-Intermediate (вище середнього)
# Technical Lead                 False  Upper-Intermediate (вище середнього)
#
#                               Дата заповнення  \
# Посада
# Junior Software Engineer  12/06/2017 13:12:25
# Senior Software Engineer  12/06/2017 13:46:24
# Software Engineer         12/06/2017 13:05:54
# System Architect          20/06/2017 18:40:40
# Technical Lead            13/06/2017 12:37:02
#
#                                                                  User.Agent  \
# Посада
# Junior Software Engineer  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# Senior Software Engineer  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# Software Engineer         Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# System Architect          Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....
# Technical Lead            Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...
#
#                            exp  current_job_exp  salary
# Посада
# Junior Software Engineer   0.5             0.50     600
# Senior Software Engineer  10.0             0.50    3500
# Software Engineer          1.0             0.00     800
# System Architect          10.0             0.25    3000
# Technical Lead             4.0             1.50    3500
# _________________________________________________________
# ІНФОРМАЦІЯ ПРО ГРУПИ:
# Група 'Junior Software Engineer' має 63 елементів
# Група 'Senior Software Engineer' має 31 елементів
# Група 'Software Engineer' має 100 елементів
# Група 'System Architect' має 2 елементів
# Група 'Technical Lead' має 11 елементів
# _________________________________________________________
# АГРЕГАЦІЯ ЗА СТОВПЦЕМ 'ПОСАДА' ДЛЯ ТАБЛИЦІ python_data:
#                            min   max
# Посада
# Junior Software Engineer   100  1250
# Senior Software Engineer  1300  9200
# Software Engineer          500  5400
# System Architect          3000  5000
# Technical Lead            1425  6200
# _________________________________________________________
# АГРЕГАЦІЯ ЗА СТОВПЦЕМ 'ПОСАДА' ДЛЯ ТАБЛИЦІ python_data З НОВИМ СТОВПЦЕМ 'avg':
#                            min   max     avg
# Посада
# Junior Software Engineer   100  1250   675.0
# Senior Software Engineer  1300  9200  5250.0
# Software Engineer          500  5400  2950.0
# System Architect          3000  5000  4000.0
# Technical Lead            1425  6200  3812.5
# ++++++++++++++++++++++++++++++++++++++++++++++++
#                            min   max     avg
# Посада
# Junior Software Engineer   100  1250   675.0
# Senior Software Engineer  1300  9200  5250.0
# Software Engineer          500  5400  2950.0
# System Architect          3000  5000  4000.0
# Technical Lead            1425  6200  3812.5
# _________________________________________________________
# ОПИСОВА СТАТИСТИКА ДЛЯ СТОВПЦЯ 'avg':
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64
