# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Load the data
data = pd.read_csv('data.csv')

# Split the data into training and test sets
X = data['x'].values.reshape(-1,1)
y = data['y'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print('X_train:', X_train.shape)
print('y_train:', y_train.shape)
print('X_test:', X_test.shape)
print('y_test:', y_test.shape)

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Вивести дані для тестування
print('Test Data:')
print('X_test:', X_test)
print('y_test:', y_test)

# Make predictions
y_pred = model.predict(X_test)
print('Predictions:', y_pred)

# Calculate the mean squared error
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

# Plot the data
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# Предсказать цену квартиры площадью 100 кв.м.
predicted_price = model.predict([[50]])
print('Predicted price for 100 sq.m:', predicted_price)
# Out:
# X_train: (8, 1)
# y_train: (8, 1)
# X_test: (2, 1)
# y_test: (2, 1)
# Test Data:
# X_test: [[34]
#  [33]]
# y_test: [[30000]
#  [20000]]
# Predictions: [[23571.42857143]
#  [21285.71428571]]
# Mean Squared Error: 21489795.918367393
# Predicted price for 100 sq.m: [[60142.85714286]]
