# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Вектор яблука
apple_vector = [7, 150, 1]

# Створення графіка
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Додавання вектора до графіка
ax.quiver(0, 0, 0, apple_vector[0], apple_vector[1], apple_vector[2], color='r', length=1)

# Налаштування осей
ax.set_xlim([0, 10])
ax.set_ylim([0, 200])
ax.set_zlim([0, 2])
ax.set_xlabel('Розмір (см)')
ax.set_ylabel('Вага (г)')
ax.set_zlabel('Колір (код)')

# Відображення графіка
plt.show()
